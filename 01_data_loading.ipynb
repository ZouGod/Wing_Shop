# %% [markdown]
# # Step 1: Data Loading
# ## Wing Shop Demand Forecasting Project
#
# This notebook loads and merges datasets from Corporación Favorita (Kaggle) or generates sample data.
#
# **Objectives:**
# - Load raw data files (train, items, stores, oil, holidays)
# - **Filter to only 1 store to reduce dataset size**
# - Merge datasets into a single dataframe
# - Generate sample data if Kaggle data is unavailable
# - Save processed data for next steps

# %%
# Import required libraries
import pandas as pd
import numpy as np
import os
import pickle
from datetime import datetime, timedelta
import warnings
warnings.filterwarnings('ignore')

# Configuration - Select which store to use (reduces dataset significantly)
SELECTED_STORE = 1  # Change this to use a different store (1-54 in Kaggle data)

print("Libraries imported successfully!")
print(f"\n*** FILTERING DATA TO STORE #{SELECTED_STORE} ONLY ***")
# Out:
# Libraries imported successfully!
#
# *** FILTERING DATA TO STORE #1 ONLY ***

# %%
# Setup project directories
BASE_DIR = os.path.dirname(os.getcwd()) if 'notebooks' in os.getcwd() else os.getcwd()
DATA_DIR = os.path.join(BASE_DIR, 'data')
MODELS_DIR = os.path.join(BASE_DIR, 'models')

# Create directories if they don't exist
os.makedirs(DATA_DIR, exist_ok=True)
os.makedirs(MODELS_DIR, exist_ok=True)

print(f"Base Directory: {BASE_DIR}")
print(f"Data Directory: {DATA_DIR}")
print(f"Models Directory: {MODELS_DIR}")
# Out:
# Base Directory: d:\CADT\InternshipII\forecasting
# Data Directory: d:\CADT\InternshipII\forecasting\data
# Models Directory: d:\CADT\InternshipII\forecasting\models

# %%
# Utility functions
def load_csv(filename, **kwargs):
    """Load CSV file from data directory"""
    filepath = os.path.join(DATA_DIR, filename)
    if os.path.exists(filepath):
        return pd.read_csv(filepath, **kwargs)
    else:
        print(f"Warning: {filename} not found in {DATA_DIR}")
        return None

def save_model(model, name):
    """Save model to pickle file"""
    filepath = os.path.join(MODELS_DIR, f"{name}.pkl")
    with open(filepath, 'wb') as f:
        pickle.dump(model, f)
    print(f"Model saved: {filepath}")

def load_model(name):
    """Load model from pickle file"""
    filepath = os.path.join(MODELS_DIR, f"{name}.pkl")
    if os.path.exists(filepath):
        with open(filepath, 'rb') as f:
            return pickle.load(f)
    return None

def get_date_features(df, date_col='date'):
    """Extract date features for modeling"""
    df = df.copy()
    df[date_col] = pd.to_datetime(df[date_col])
    df['year'] = df[date_col].dt.year
    df['month'] = df[date_col].dt.month
    df['day'] = df[date_col].dt.day
    df['dayofweek'] = df[date_col].dt.dayofweek
    df['weekofyear'] = df[date_col].dt.isocalendar().week.astype(int)
    df['is_weekend'] = df['dayofweek'].isin([5, 6]).astype(int)
    df['is_month_start'] = df[date_col].dt.is_month_start.astype(int)
    df['is_month_end'] = df[date_col].dt.is_month_end.astype(int)
    return df

print("Utility functions defined!")
# Out:
# Utility functions defined!

# %%
# Generate sample data for ONLY 1 store
def generate_sample_data():
    """
    Generate sample data if Kaggle dataset is not available.
    Simulates realistic grocery store sales patterns for Cambodia market.
    Only generates data for 1 store to keep dataset small.
    """
    np.random.seed(42)
    
    # Generate dates for 2 years
    start_date = datetime(2024, 1, 1)
    dates = [start_date + timedelta(days=i) for i in range(730)]
    
    products = ['Rice', 'Water', 'Cooking Oil', 'Instant Noodles', 'Sugar', 'Soap', 'Milk', 'Bread']
    
    data = []
    store = SELECTED_STORE  # Only 1 store
    store_factor = np.random.uniform(0.8, 1.2)
    
    for product_idx, product in enumerate(products):
        # Base demand varies by product
        base_demand = [150, 200, 80, 120, 60, 40, 90, 100][product_idx]
        
        for date in dates:
            # Day of week effect (higher on weekends)
            dow_effect = 1.3 if date.weekday() >= 5 else 1.0
            
            # Monthly seasonality
            month_effect = 1 + 0.1 * np.sin(2 * np.pi * date.month / 12)
            
            # Holiday effect (simplified)
            is_holiday = date.day in [1, 15] or date.month == 12
            holiday_effect = 1.5 if is_holiday else 1.0
            
            # Economic shock (simulating Cambodia-Thailand conflict impact)
            if date >= datetime(2025, 6, 1):
                shock_effect = 0.85  # 15% reduction due to supply chain issues
            else:
                shock_effect = 1.0
            
            # Random promotion
            on_promotion = np.random.random() < 0.1
            promo_effect = 1.4 if on_promotion else 1.0
            
            # Calculate sales with noise
            sales = int(
                base_demand * store_factor * dow_effect * month_effect * 
                holiday_effect * shock_effect * promo_effect * 
                np.random.uniform(0.8, 1.2)
            )
            sales = max(0, sales)
            
            data.append({
                'date': date.strftime('%Y-%m-%d'),
                'store_nbr': store,
                'product': product,
                'family': ['GROCERY I', 'BEVERAGES', 'GROCERY I', 'GROCERY II', 
                          'GROCERY I', 'CLEANING', 'DAIRY', 'BREAD/BAKERY'][product_idx],
                'unit_sales': sales,
                'onpromotion': on_promotion,
                'is_holiday': is_holiday
            })
    
    df = pd.DataFrame(data)
    
    # Save generated data
    df.to_csv(os.path.join(DATA_DIR, 'sample_sales.csv'), index=False)
    print(f"Sample data generated: {len(df):,} records (1 store, 8 products, 730 days)")
    
    return df

print("Sample data generator defined (single store mode)!")
# Out:
# Sample data generator defined (single store mode)!

# %% [markdown]
# ## 1.1 Load Kaggle Data (Single Store Only)

# %%
print("=" * 60)
print("STEP 1: DATA LOADING (SINGLE STORE MODE)")
print("=" * 60)
print(f"\nLoading data for Store #{SELECTED_STORE} only...")

# Load only the selected store from train.csv to save memory
train_path = os.path.join(DATA_DIR, 'train.csv')

if os.path.exists(train_path):
    # Read in chunks and filter to single store
    print("\nReading train.csv in chunks (filtering to single store)...")
    chunks = []
    chunk_size = 500000
    
    for chunk in pd.read_csv(train_path, parse_dates=['date'], 
                              dtype={'onpromotion': str}, chunksize=chunk_size):
        filtered = chunk[chunk['store_nbr'] == SELECTED_STORE]
        chunks.append(filtered)
        print(f"  Processed chunk: kept {len(filtered):,} rows for store {SELECTED_STORE}")
    
    train = pd.concat(chunks, ignore_index=True)
    print(f"\nTotal rows after filtering: {len(train):,}")
else:
    train = None
    print("train.csv not found")

# Load other files (these are small)
items = load_csv(r'D:\CADT\InternshipII\forecasting\data\items.csv')
stores = load_csv(r'D:\CADT\InternshipII\forecasting\data\stores.csv')
oil = load_csv(r'D:\CADT\InternshipII\forecasting\data\oil.csv', parse_dates=['date'])
holidays = load_csv(r'D:\CADT\InternshipII\forecasting\data\holidays_events.csv', parse_dates=['date'])
transactions = load_csv(r'D:\CADT\InternshipII\forecasting\data\transactions.csv', parse_dates=['date'])
# Filter transactions to single store too
if transactions is not None:
    transactions = transactions[transactions['store_nbr'] == SELECTED_STORE]
    print(f"Transactions filtered: {len(transactions):,} rows")
# Out:
# ============================================================
# STEP 1: DATA LOADING (SINGLE STORE MODE)
# ============================================================
#
# Loading data for Store #1 only...
#
# Reading train.csv in chunks (filtering to single store)...
#   Processed chunk: kept 12,129 rows for store 1
#   Processed chunk: kept 11,367 rows for store 1
#   Processed chunk: kept 11,287 rows for store 1
#   Processed chunk: kept 10,221 rows for store 1
#   Processed chunk: kept 11,544 rows for store 1
#   Processed chunk: kept 11,732 rows for store 1
#   Processed chunk: kept 11,498 rows for store 1
#   Processed chunk: kept 10,405 rows for store 1
#   Processed chunk: kept 11,813 rows for store 1
#   Processed chunk: kept 11,388 rows for store 1
#   Processed chunk: kept 10,822 rows for store 1
#   Processed chunk: kept 11,788 rows for store 1
#   Processed chunk: kept 10,672 rows for store 1
#   Processed chunk: kept 11,341 rows for store 1
#   Processed chunk: kept 10,750 rows for store 1
#   Processed chunk: kept 11,017 rows for store 1
#   Processed chunk: kept 12,204 rows for store 1
#   Processed chunk: kept 10,795 rows for store 1
#   Processed chunk: kept 11,091 rows for store 1
#   Processed chunk: kept 10,498 rows for store 1
#   Processed chunk: kept 10,237 rows for store 1
#   Processed chunk: kept 11,004 rows for store 1
#   Processed chunk: kept 10,959 rows for store 1
#   Processed chunk: kept 11,615 rows for store 1
#   Processed chunk: kept 11,030 rows for store 1
#   Processed chunk: kept 11,654 rows for store 1
#   Processed chunk: kept 10,217 rows for store 1
#   Processed chunk: kept 12,465 rows for store 1
#   Processed chunk: kept 10,974 rows for store 1
#   Processed chunk: kept 11,488 rows for store 1
#   Processed chunk: kept 10,928 rows for store 1
#   Processed chunk: kept 10,739 rows for store 1
#   Processed chunk: kept 10,932 rows for store 1
#   Processed chunk: kept 11,764 rows for store 1
#   Processed chunk: kept 12,216 rows for store 1
#   Processed chunk: kept 10,479 rows for store 1
#   Processed chunk: kept 11,808 rows for store 1
#   Processed chunk: kept 11,245 rows for store 1
#   Processed chunk: kept 10,861 rows for store 1
#   Processed chunk: kept 10,951 rows for store 1
#   Processed chunk: kept 11,915 rows for store 1
#   Processed chunk: kept 10,353 rows for store 1
#   Processed chunk: kept 11,905 rows for store 1
#   Processed chunk: kept 10,802 rows for store 1
#   Processed chunk: kept 11,162 rows for store 1
#   Processed chunk: kept 11,241 rows for store 1
#   Processed chunk: kept 11,585 rows for store 1
#   Processed chunk: kept 11,150 rows for store 1
#   Processed chunk: kept 11,467 rows for store 1
#   Processed chunk: kept 11,785 rows for store 1
#   Processed chunk: kept 9,839 rows for store 1
#   Processed chunk: kept 11,583 rows for store 1
#   Processed chunk: kept 11,720 rows for store 1
#   Processed chunk: kept 11,634 rows for store 1
#   Processed chunk: kept 10,708 rows for store 1
#   Processed chunk: kept 11,698 rows for store 1
#   Processed chunk: kept 10,841 rows for store 1
#   Processed chunk: kept 10,436 rows for store 1
#   Processed chunk: kept 10,477 rows for store 1
#   Processed chunk: kept 11,873 rows for store 1
#   Processed chunk: kept 11,164 rows for store 1
#   Processed chunk: kept 10,890 rows for store 1
#   Processed chunk: kept 10,789 rows for store 1
#   Processed chunk: kept 10,803 rows for store 1
#   Processed chunk: kept 11,110 rows for store 1
#   Processed chunk: kept 11,959 rows for store 1
#   Processed chunk: kept 11,014 rows for store 1
#   Processed chunk: kept 10,923 rows for store 1
#   Processed chunk: kept 10,299 rows for store 1
#   Processed chunk: kept 11,091 rows for store 1
#   Processed chunk: kept 11,012 rows for store 1
#   Processed chunk: kept 10,955 rows for store 1
#   Processed chunk: kept 11,125 rows for store 1
#   Processed chunk: kept 11,199 rows for store 1
#   Processed chunk: kept 11,426 rows for store 1
#   Processed chunk: kept 11,843 rows for store 1
#   Processed chunk: kept 8,874 rows for store 1
#   Processed chunk: kept 10,171 rows for store 1
#   Processed chunk: kept 11,564 rows for store 1
#   Processed chunk: kept 9,873 rows for store 1
#   Processed chunk: kept 11,698 rows for store 1
#   Processed chunk: kept 10,354 rows for store 1
#   Processed chunk: kept 10,140 rows for store 1
#   Processed chunk: kept 10,326 rows for store 1
#   Processed chunk: kept 10,085 rows for store 1
#   Processed chunk: kept 10,431 rows for store 1
#   Processed chunk: kept 10,283 rows for store 1
#   Processed chunk: kept 10,298 rows for store 1
#   Processed chunk: kept 9,716 rows for store 1
#   Processed chunk: kept 10,262 rows for store 1
#   Processed chunk: kept 10,357 rows for store 1
#   Processed chunk: kept 9,367 rows for store 1
#   Processed chunk: kept 10,829 rows for store 1
#   Processed chunk: kept 9,673 rows for store 1
#   Processed chunk: kept 11,535 rows for store 1
#   Processed chunk: kept 10,717 rows for store 1
#   Processed chunk: kept 9,949 rows for store 1
#   Processed chunk: kept 9,831 rows for store 1
#   Processed chunk: kept 11,843 rows for store 1
#   Processed chunk: kept 10,466 rows for store 1
#   Processed chunk: kept 10,366 rows for store 1
#   Processed chunk: kept 8,158 rows for store 1
#   Processed chunk: kept 12,037 rows for store 1
#   Processed chunk: kept 10,042 rows for store 1
#   Processed chunk: kept 9,934 rows for store 1
#   Processed chunk: kept 10,192 rows for store 1
#   Processed chunk: kept 9,838 rows for store 1
#   Processed chunk: kept 10,060 rows for store 1
#   Processed chunk: kept 9,940 rows for store 1
#   Processed chunk: kept 10,025 rows for store 1
#   Processed chunk: kept 10,369 rows for store 1
#   Processed chunk: kept 8,643 rows for store 1
#   Processed chunk: kept 10,367 rows for store 1
#   Processed chunk: kept 10,870 rows for store 1
#   Processed chunk: kept 10,287 rows for store 1
#   Processed chunk: kept 10,546 rows for store 1
#   Processed chunk: kept 9,359 rows for store 1
#   Processed chunk: kept 8,238 rows for store 1
#   Processed chunk: kept 11,476 rows for store 1
#   Processed chunk: kept 9,078 rows for store 1
#   Processed chunk: kept 10,929 rows for store 1
#   Processed chunk: kept 7,802 rows for store 1
#   Processed chunk: kept 10,515 rows for store 1
#   Processed chunk: kept 9,417 rows for store 1
#   Processed chunk: kept 10,865 rows for store 1
#   Processed chunk: kept 9,110 rows for store 1
#   Processed chunk: kept 10,867 rows for store 1
#   Processed chunk: kept 9,676 rows for store 1
#   Processed chunk: kept 9,259 rows for store 1
#   Processed chunk: kept 9,118 rows for store 1
#   Processed chunk: kept 11,550 rows for store 1
#   Processed chunk: kept 8,788 rows for store 1
#   Processed chunk: kept 9,251 rows for store 1
#   Processed chunk: kept 9,456 rows for store 1
#   Processed chunk: kept 9,150 rows for store 1
#   Processed chunk: kept 11,201 rows for store 1
#   Processed chunk: kept 9,613 rows for store 1
#   Processed chunk: kept 11,047 rows for store 1
#   Processed chunk: kept 9,478 rows for store 1
#   Processed chunk: kept 7,999 rows for store 1
#   Processed chunk: kept 9,273 rows for store 1
#   Processed chunk: kept 11,180 rows for store 1
#   Processed chunk: kept 9,298 rows for store 1
#   Processed chunk: kept 9,050 rows for store 1
#   Processed chunk: kept 9,981 rows for store 1
#   Processed chunk: kept 11,184 rows for store 1
#   Processed chunk: kept 9,314 rows for store 1
#   Processed chunk: kept 9,217 rows for store 1
#   Processed chunk: kept 10,254 rows for store 1
#   Processed chunk: kept 9,919 rows for store 1
#   Processed chunk: kept 9,701 rows for store 1
#   Processed chunk: kept 9,300 rows for store 1
#   Processed chunk: kept 9,801 rows for store 1
#   Processed chunk: kept 11,043 rows for store 1
#   Processed chunk: kept 9,977 rows for store 1
#   Processed chunk: kept 9,561 rows for store 1
#   Processed chunk: kept 10,129 rows for store 1
#   Processed chunk: kept 9,137 rows for store 1
#   Processed chunk: kept 9,481 rows for store 1
#   Processed chunk: kept 11,234 rows for store 1
#   Processed chunk: kept 8,944 rows for store 1
#   Processed chunk: kept 9,278 rows for store 1
#   Processed chunk: kept 9,346 rows for store 1
#   Processed chunk: kept 11,009 rows for store 1
#   Processed chunk: kept 9,733 rows for store 1
#   Processed chunk: kept 9,151 rows for store 1
#   Processed chunk: kept 11,190 rows for store 1
#   Processed chunk: kept 9,429 rows for store 1
#   Processed chunk: kept 9,978 rows for store 1
#   Processed chunk: kept 9,206 rows for store 1
#   Processed chunk: kept 9,370 rows for store 1
#   Processed chunk: kept 11,292 rows for store 1
#   Processed chunk: kept 9,875 rows for store 1
#   Processed chunk: kept 9,457 rows for store 1
#   Processed chunk: kept 9,397 rows for store 1
#   Processed chunk: kept 8,327 rows for store 1
#   Processed chunk: kept 9,949 rows for store 1
#   Processed chunk: kept 11,025 rows for store 1
#   Processed chunk: kept 9,170 rows for store 1
#   Processed chunk: kept 9,778 rows for store 1
#   Processed chunk: kept 10,172 rows for store 1
#   Processed chunk: kept 9,352 rows for store 1
#   Processed chunk: kept 11,489 rows for store 1
#   Processed chunk: kept 9,441 rows for store 1
#   Processed chunk: kept 9,806 rows for store 1
#   Processed chunk: kept 10,221 rows for store 1
#   Processed chunk: kept 9,702 rows for store 1
#   Processed chunk: kept 11,675 rows for store 1
#   Processed chunk: kept 10,075 rows for store 1
#   Processed chunk: kept 9,713 rows for store 1
#   Processed chunk: kept 9,513 rows for store 1
#   Processed chunk: kept 8,270 rows for store 1
#   Processed chunk: kept 9,885 rows for store 1
#   Processed chunk: kept 9,677 rows for store 1
#   Processed chunk: kept 9,768 rows for store 1
#   Processed chunk: kept 10,335 rows for store 1
#   Processed chunk: kept 9,638 rows for store 1
#   Processed chunk: kept 9,923 rows for store 1
#   Processed chunk: kept 9,923 rows for store 1
#   Processed chunk: kept 9,937 rows for store 1
#   Processed chunk: kept 8,714 rows for store 1
#   Processed chunk: kept 10,236 rows for store 1
#   Processed chunk: kept 9,607 rows for store 1
#   Processed chunk: kept 7,963 rows for store 1
#   Processed chunk: kept 10,254 rows for store 1
#   Processed chunk: kept 10,584 rows for store 1
#   Processed chunk: kept 9,969 rows for store 1
#   Processed chunk: kept 9,906 rows for store 1
#   Processed chunk: kept 8,623 rows for store 1
#   Processed chunk: kept 9,986 rows for store 1
#   Processed chunk: kept 10,121 rows for store 1
#   Processed chunk: kept 9,981 rows for store 1
#   Processed chunk: kept 8,305 rows for store 1
#   Processed chunk: kept 9,868 rows for store 1
#   Processed chunk: kept 9,610 rows for store 1
#   Processed chunk: kept 9,194 rows for store 1
#   Processed chunk: kept 7,883 rows for store 1
#   Processed chunk: kept 10,024 rows for store 1
#   Processed chunk: kept 10,644 rows for store 1
#   Processed chunk: kept 9,938 rows for store 1
#   Processed chunk: kept 9,946 rows for store 1
#   Processed chunk: kept 8,529 rows for store 1
#   Processed chunk: kept 10,360 rows for store 1
#   Processed chunk: kept 9,910 rows for store 1
#   Processed chunk: kept 9,276 rows for store 1
#   Processed chunk: kept 7,929 rows for store 1
#   Processed chunk: kept 9,607 rows for store 1
#   Processed chunk: kept 10,229 rows for store 1
#   Processed chunk: kept 6,989 rows for store 1
#   Processed chunk: kept 9,989 rows for store 1
#   Processed chunk: kept 10,236 rows for store 1
#   Processed chunk: kept 9,457 rows for store 1
#   Processed chunk: kept 7,807 rows for store 1
#   Processed chunk: kept 9,627 rows for store 1
#   Processed chunk: kept 9,779 rows for store 1
#   Processed chunk: kept 7,833 rows for store 1
#   Processed chunk: kept 10,439 rows for store 1
#   Processed chunk: kept 9,725 rows for store 1
#   Processed chunk: kept 7,605 rows for store 1
#   Processed chunk: kept 10,306 rows for store 1
#   Processed chunk: kept 9,555 rows for store 1
#   Processed chunk: kept 9,956 rows for store 1
#   Processed chunk: kept 8,273 rows for store 1
#   Processed chunk: kept 9,622 rows for store 1
#   Processed chunk: kept 9,472 rows for store 1
#   Processed chunk: kept 9,701 rows for store 1
#   Processed chunk: kept 10,077 rows for store 1
#   Processed chunk: kept 7,633 rows for store 1
#   Processed chunk: kept 9,501 rows for store 1
#   Processed chunk: kept 9,532 rows for store 1
#   Processed chunk: kept 7,128 rows for store 1
#
# Total rows after filtering: 2,562,153
# Transactions filtered: 1,676 rows

# %%
# Check if Kaggle data exists, otherwise generate sample data
if train is None:
    print("\nKaggle dataset not found. Generating sample data...")
    df = generate_sample_data()
else:
    print(f"\n[1/6] Train data (Store #{SELECTED_STORE}): {train.shape}")
    print(f"[2/6] Items data loaded: {items.shape if items is not None else 'N/A'}")
    print(f"[3/6] Stores data loaded: {stores.shape if stores is not None else 'N/A'}")
    print(f"[4/6] Oil data loaded: {oil.shape if oil is not None else 'N/A'}")
    print(f"[5/6] Holidays data loaded: {holidays.shape if holidays is not None else 'N/A'}")
    print(f"[6/6] Transactions (Store #{SELECTED_STORE}): {transactions.shape if transactions is not None else 'N/A'}")
    
    # Merge datasets
    print("\nMerging datasets...")
    
    # Merge items info
    if items is not None:
        df = train.merge(items, on='item_nbr', how='left')
    else:
        df = train.copy()
    
    # Merge store info
    if stores is not None:
        df = df.merge(stores, on='store_nbr', how='left')
    
    # Merge oil prices
    if oil is not None:
        df = df.merge(oil, on='date', how='left')
        df['dcoilwtico'] = df['dcoilwtico'].fillna(method='ffill')
    
    # Merge holidays
    if holidays is not None:
        holidays_national = holidays[holidays['locale'] == 'National'][['date', 'type', 'transferred']]
        holidays_national = holidays_national.rename(columns={'type': 'holiday_type'})
        df = df.merge(holidays_national, on='date', how='left')
        df['is_holiday'] = df['holiday_type'].notna().astype(int)
    
    # Merge transactions
    if transactions is not None:
        df = df.merge(transactions, on=['date', 'store_nbr'], how='left')
    
    print(f"\nFinal merged dataset (Store #{SELECTED_STORE} only): {df.shape}")
# Out:
# [1/6] Train data (Store #1): (2562153, 6)
# [2/6] Items data loaded: (4100, 4)
# [3/6] Stores data loaded: (54, 5)
# [4/6] Oil data loaded: (1218, 2)
# [5/6] Holidays data loaded: (350, 6)
# [6/6] Transactions (Store #1): (1676, 3)
#
# Merging datasets...
#
# Final merged dataset (Store #1 only): (2568576, 18)

# %% [markdown]
# ## 1.2 Aggregate Daily Sales

# %%
def aggregate_daily_sales(df):
    """Aggregate sales by date, store, and product family."""
    print("\nAggregating daily sales by family...")
    
    # Check which columns exist
    group_cols = ['date']
    
    if 'store_nbr' in df.columns:
        group_cols.append('store_nbr')
    
    if 'family' in df.columns:
        group_cols.append('family')
    elif 'product' in df.columns:
        group_cols.append('product')
    
    # Aggregate
    agg_dict = {'unit_sales': 'sum'}
    
    if 'onpromotion' in df.columns:
        if df['onpromotion'].dtype == 'object':
            df['onpromotion'] = df['onpromotion'].map({'True': 1, 'False': 0, True: 1, False: 0}).fillna(0)
        agg_dict['onpromotion'] = 'sum'
    
    if 'transactions' in df.columns:
        agg_dict['transactions'] = 'mean'
    
    if 'dcoilwtico' in df.columns:
        agg_dict['dcoilwtico'] = 'mean'
    
    if 'is_holiday' in df.columns:
        agg_dict['is_holiday'] = 'max'
    
    df_agg = df.groupby(group_cols).agg(agg_dict).reset_index()
    
    print(f"Aggregated data shape: {df_agg.shape}")
    
    return df_agg

# Apply aggregation
df_agg = aggregate_daily_sales(df)
# Out:
# Aggregating daily sales by family...
# Aggregated data shape: (42775, 8)

# %% [markdown]
# ## 1.3 Add Date Features and Save

# %%
# Add date features
df_agg = get_date_features(df_agg)

# Display data overview
print("\n" + "=" * 60)
print(f"DATA OVERVIEW (Store #{SELECTED_STORE} Only)")
print("=" * 60)
print(f"\nColumns: {list(df_agg.columns)}")
print(f"\nDate range: {df_agg['date'].min()} to {df_agg['date'].max()}")
print(f"\nData shape: {df_agg.shape}")

# Show unique families/products
if 'family' in df_agg.columns:
    print(f"\nUnique product families: {df_agg['family'].nunique()}")
    print(df_agg['family'].unique()[:10])
elif 'product' in df_agg.columns:
    print(f"\nUnique products: {df_agg['product'].nunique()}")
    print(df_agg['product'].unique())
# Out:
# ============================================================
# DATA OVERVIEW (Store #1 Only)
# ============================================================
#
# Columns: ['date', 'store_nbr', 'family', 'unit_sales', 'onpromotion', 'transactions', 'dcoilwtico', 'is_holiday', 'year', 'month', 'day', 'dayofweek', 'weekofyear', 'is_weekend', 'is_month_start', 'is_month_end']
#
# Date range: 2013-01-02 00:00:00 to 2017-08-15 00:00:00
#
# Data shape: (42775, 16)
#
# Unique product families: 32
# ['AUTOMOTIVE' 'BEAUTY' 'BEVERAGES' 'BREAD/BAKERY' 'CLEANING' 'DAIRY'
#  'DELI' 'EGGS' 'FROZEN FOODS' 'GROCERY I']

# %%
# Show sample data
df_agg.head(10)
# Out:
#         date  store_nbr        family  unit_sales  onpromotion  transactions  \
# 0 2013-01-02          1    AUTOMOTIVE       2.000          0.0        2111.0
# 1 2013-01-02          1        BEAUTY       2.000          0.0        2111.0
# 2 2013-01-02          1     BEVERAGES    1091.000          0.0        2111.0
# 3 2013-01-02          1  BREAD/BAKERY     470.652          0.0        2111.0
# 4 2013-01-02          1      CLEANING    1060.000          0.0        2111.0
# 5 2013-01-02          1         DAIRY     579.000          0.0        2111.0
# 6 2013-01-02          1          DELI     164.069          0.0        2111.0
# 7 2013-01-02          1          EGGS     246.000          0.0        2111.0
# 8 2013-01-02          1  FROZEN FOODS     131.000          0.0        2111.0
# 9 2013-01-02          1     GROCERY I    2652.000          0.0        2111.0
#
#    dcoilwtico  is_holiday  year  month  day  dayofweek  weekofyear  \
# 0       93.14           0  2013      1    2          2           1
# 1       93.14           0  2013      1    2          2           1
# 2       93.14           0  2013      1    2          2           1
# 3       93.14           0  2013      1    2          2           1
# 4       93.14           0  2013      1    2          2           1
# 5       93.14           0  2013      1    2          2           1
# 6       93.14           0  2013      1    2          2           1
# 7       93.14           0  2013      1    2          2           1
# 8       93.14           0  2013      1    2          2           1
# 9       93.14           0  2013      1    2          2           1
#
#    is_weekend  is_month_start  is_month_end
# 0           0               0             0
# 1           0               0             0
# 2           0               0             0
# 3           0               0             0
# 4           0               0             0
# 5           0               0             0
# 6           0               0             0
# 7           0               0             0
# 8           0               0             0
# 9           0               0             0

# %%
# Memory usage comparison
print("\n" + "=" * 60)
print("MEMORY SAVINGS")
print("=" * 60)
mem_usage = df_agg.memory_usage(deep=True).sum() / 1024 / 1024
print(f"Current dataset memory: {mem_usage:.2f} MB")
print(f"Estimated full dataset (54 stores): {mem_usage * 54:.2f} MB")
print(f"Memory saved by using 1 store: ~{mem_usage * 53:.2f} MB")
# Out:
# ============================================================
# MEMORY SAVINGS
# ============================================================
# Current dataset memory: 6.98 MB
# Estimated full dataset (54 stores): 376.93 MB
# Memory saved by using 1 store: ~369.95 MB

# %%
# Save processed data
filepath = os.path.join(DATA_DIR, r'D:\CADT\InternshipII\forecasting\data\processed_sales.csv')
df_agg.to_csv(filepath, index=False)

print(f"\nProcessed data saved to: {filepath}")
print("\n" + "=" * 60)
print(f"DATA LOADING COMPLETE! (Store #{SELECTED_STORE} only)")
print("=" * 60)
# Out:
# Processed data saved to: D:\CADT\InternshipII\forecasting\data\processed_sales.csv
#
# ============================================================
# DATA LOADING COMPLETE! (Store #1 only)
# ============================================================
